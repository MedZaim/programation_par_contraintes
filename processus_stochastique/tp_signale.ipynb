# %%
# Importation de modules nécessaires
# Pour les modules dont le nom est un peu long,
# on peut leur donner un nom plus cours avec `as`
import numpy as np
import matplotlib.pyplot as plt

# Abscisses sur lesquelles sera calculée la sinusoïde :
# un point tous les 0,1 s entre 0 et 10 s
n = np.arange(0, 10, 0.01)

# Fréquence de la sinuoïde
f = 0.2

# Sinusoïde : c'est tout simple, il suffit d'écrire
# l'expression mathématique
x = np.sin(2*np.pi*f*n)

# Création d'une figure, dont on définit la taille
plt.figure(figsize=(8,4))


# Affichage de la sinusoïde (dans la figure créée)
plt.plot(n, x, label="sinusoïde")

# Légende
plt.legend()
# Légende des axes et titre
plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("Une belle sinusoïde")

# Affichage (pas toujours nécessaire, mais parfois indispensable)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


n = np.arange(0, 1, 0.005)

# Amplitude
A = 2
f = 5
phy = np.pi/3
# Sinusoïde : c'est tout simple, il suffit d'écrire
# l'expression mathématique
x = A * np.sin(2*np.pi*f*n + phy)

# Création d'une figure, dont on définit la taille
plt.figure(figsize=(8,4))


# Affichage de la sinusoïde (dans la figure créée)
plt.plot(n, x, label="sinusoïde")

# Légende
plt.legend()
# Légende des axes et titre
plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("Une belle sinusoïde")

# Affichage (pas toujours nécessaire, mais parfois indispensable)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


n = np.arange(0, 10, 0.01)

# Amplitude
A = 2
f = 2
a = 0.5
#phy = np.pi/3
# Sinusoïde : c'est tout simple, il suffit d'écrire
# l'expression mathématique
x = A * np.exp(-a * n) * np.sin(2*np.pi*f*n)

# Création d'une figure, dont on définit la taille
plt.figure(figsize=(8,4))


# Affichage de la sinusoïde (dans la figure créée)
plt.plot(n, x, label="sinusoïde")

# Légende
plt.legend()
# Légende des axes et titre
plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("Une belle sinusoïde")

# Affichage (pas toujours nécessaire, mais parfois indispensable)
plt.show()

# %%
# Define the rect function manually using np.where
def rect(x):
    return np.where(np.abs(x) <= 0.5, 1, 0)

n = np.arange(0, 10, 0.01)

# Amplitude
A = 3
f = 2

N = 5
m = 4
#phy = np.pi/3
#  c'est tout simple, il suffit d'écrire
# l'expression mathématique
z = A * rect((n - m)/N) 

# Création d'une figure, dont on définit la taille
plt.figure(figsize=(8,4))


#(dans la figure créée)
plt.stem(n, z, label="porte")

# Légende
plt.legend()
# Légende des axes et titre
plt.xlabel("$n$")
plt.ylabel("$z[n]$")
plt.title("Une belle le signale porte")

# Affichage (pas toujours nécessaire, mais parfois indispensable)
plt.show()

# %%
N=32

x= np.zeros(N)
x[0]=1



# Création d'une figure, dont on définit la taille
plt.figure(1)


# Affichage de la sinusoïde (dans la figure créée)
plt.stem(x)


#plt.legend()

plt.xlabel("$x$")
plt.ylabel("$delta(x)$")
plt.title("Un Dirac")
plt.grid(True)
# Affichage (pas toujours nécessaire, mais parfois indispensable)
plt.show()

# %%
N=32

x= np.zeros(N)
y= np.ones(N)
z= np.concatenate((x,y))
t= np.arange(-N,N,1)


plt.figure(2)

plt.stem(t,z)

#plt.legend()

plt.xlabel("$x$")
plt.ylabel("$delta(x)$")
plt.title("Un echlon")
plt.grid(True)
# Affichage (pas toujours nécessaire, mais parfois indispensable)
plt.show()

# %%
N=50
Te=0.1
t=np.arange(0,N)*Te
x= A*np.concatenate((np.zeros(20),np.ones(10),np.zeros(20)))
plt.figure(5)
plt.subplot(221)
plt.plot(x)
plt.grid(True)
plt.xlabel("S")
plt.ylabel("Amp")

plt.subplot(222)
plt.plot(x)
plt.grid(True)
plt.xlabel("S")
plt.ylabel("Amp")

plt.subplot(223)
plt.plot(x)
plt.grid(True)
plt.xlabel("S")
plt.ylabel("Amp")


tt = np.arange(-(N-1),N)*Te
Rx = np.correlate(x,x,mode='full')
plt.subplot(224)
plt.plot(tt,Rx)
plt.grid(True)
plt.xlabel("S")
plt.ylabel("Amp")
plt.title("Autocorr")
# Out:
# Text(0.5, 1.0, 'Autocorr')
